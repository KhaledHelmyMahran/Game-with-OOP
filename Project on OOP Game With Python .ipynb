# %%
class Game:
    #constructor for the main game 
    def __init__(self):
        print('welcome in the full game')
        print('choose your Game from our collection ')
        print('press [1] : play Even odd game ')
        print('press [2] : play sum average ')    
        print('press [3] : play multipliacation game ')
        self.choices()
    #available choices  
    def choices(self):
        while True:
            user_choice = input('enter your choice of the game : ')
            try:
                user_choice = int(user_choice)
                if user_choice == 1 :
                    self.Even_Odd_Game()

                elif user_choice == 2 :
                    self.Sum_average_Game()
                    

                elif user_choice == 3 :
                    self.Multiplication_Game()
                    
                else:
                    print('please choose between 1,2 or 3 ')
            except ValueError:
                print('enter A valid number ')
      ##################################################################################################################
    #even odd game code 
    def Even_Odd_Game(self):
        #this project to valid number
        print("Welcome to The Even-Odd Game")
        print("please enter A Number ..... And I will Tell You If if Even Or Odd   ")
        print("If You Want To Exit The Game Enter ' x'  ")
        while True:
            number = input("enter your num : ")
            if number == 'x':
                print('closing the game')
                print('thanks.......')
                break
            try:
                number = int(number)
                if number % 2 == 0 :
                    print(" Even Number")
                else:
                    print(" Odd Number ")
            except ValueError:
                    print("please enter valid number")
            print('------------------------------------------------')
    ########################################################################################################################
            #sum agerage count code 
    def Sum_average_Game(self):
        print("This Game Will Take Several Number And Print The Sum , Average , Count Of Number ")
        print("\n")
        print("If You Want To Exit Enter 'S' to Calculate Sum ")
        print("\n")

        def sum():
            print("sum , count , avg ")
            sum_num = 0 
            count = 0 
            avg = 0
            while True:
                numbers = input("enter number to add : ")    
                if numbers == 's':
                    break
                else:
                    try:
                        numbers = int(numbers)
                    except:
                        print("enter valid number")
                        continue
                    sum_num += numbers
                    count += 1
            avg = sum_num / count
            return sum_num , count , avg
        print(sum())
    ###########################################################################################################################
    # multipliaction table 
    def Multiplication_Game(self):
         #this project to print Multiplication table
        try:
            first_number=int(input("enter the first number of  Multiplication table : "))
            second_number=int(input("enter the second number of  Multiplication table : "))
            for x in range (first_number,second_number+1):
                for y in range(1,12):
                    print(x ,"x",y ,"= " ,x*y)
            print("----------------------------------------------------------")
        except ValueError:
            print("enter number not string ")
#create object from the class 
game1=Game()
# Out:
# welcome in the full game
# choose your Game from our collection
# press [1] : play Even odd game
# press [2] : play sum average
# press [3] : play multipliacation game
# enter your choice of the game : 1
# Welcome to The Even-Odd Game
# please enter A Number ..... And I will Tell You If if Even Or Odd
# If You Want To Exit The Game Enter ' x'
# enter your num : 2
#  Even Number
# ------------------------------------------------
# enter your num : 3
#  Odd Number
# ------------------------------------------------
